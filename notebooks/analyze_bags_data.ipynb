# %% [markdown]
# # Analyze Bags Data in Dataset
# This notebook will help you check the number, label distribution, and image path validity for "Bags" items in your dataset.

# %% [markdown]
# # Generalized Analysis for All Item Types
# This section analyzes the dataset for **all item types**. For each type, it will:
# - Show the number of samples
# - Display condition score statistics
# - Show output class distribution
# - Check for missing images
# - Summarize years used, condition, and description fields

# %%
import pandas as pd
import os
from collections import Counter

# Load the dataset
csv_path = '../data/full_items_extended_dataset.csv'
df = pd.read_csv(csv_path)

# Filter for Bags
bags_df = df[df['item_type'].str.lower() == 'bags']
print(f"Number of 'Bags' samples: {len(bags_df)}")
bags_df.head()
# Out:
# Number of 'Bags' samples: 45
#     item_type  years_used condition                              description  \
# 405      Bags           1   Working  Zip works fine, fabric a bit discolored
# 406      Bags           2   Working  Zip works fine, fabric a bit discolored
# 407      Bags           3   Working  Zip works fine, fabric a bit discolored
# 408      Bags           4   Working  Zip works fine, fabric a bit discolored
# 409      Bags           5   Working  Zip works fine, fabric a bit discolored
#
#     image_damage  condition_score                output  \
# 405          Low             0.95  Refurbish and Resell
# 406          Low             0.92  Refurbish and Resell
# 407          Low             0.89  Refurbish and Resell
# 408          Low             0.86  Refurbish and Resell
# 409          Low             0.83  Refurbish and Resell
#
#                                             image_path
# 405  waste_classifier/data/images/used-school-bags-...
# 406           waste_classifier/data/images/images.jpeg
# 407                   images/bags_working_low_3yrs.jpg
# 408                   images/bags_working_low_4yrs.jpg
# 409                   images/bags_working_low_5yrs.jpg

# %%
# Check condition_score and output distribution for Bags
print("Condition score stats for Bags:")
print(bags_df['condition_score'].describe())
print("\nOutput class counts for Bags:")
print(bags_df['output'].value_counts())
# Out:
# Condition score stats for Bags:
# count    45.000000
# mean      0.364889
# std       0.282607
# min       0.050000
# 25%       0.060000
# 50%       0.330000
# 75%       0.590000
# max       0.950000
# Name: condition_score, dtype: float64
#
# Output class counts for Bags:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64

# %%
# Check if image files exist for Bags
image_dir = '../data/images/'
def check_image_exists(image_path):
    return os.path.exists(os.path.join(image_dir, os.path.basename(image_path)))
bags_df['image_exists'] = bags_df['image_path'].apply(check_image_exists)
missing_images = bags_df[~bags_df['image_exists']]
print(f"Missing images for Bags: {len(missing_images)}")
if not missing_images.empty:
    print(missing_images[['image_path']])
# Out:
# Missing images for Bags: 43
#                                    image_path
# 407          images/bags_working_low_3yrs.jpg
# 408          images/bags_working_low_4yrs.jpg
# 409          images/bags_working_low_5yrs.jpg
# 410     images/bags_working_moderate_1yrs.jpg
# 411     images/bags_working_moderate_2yrs.jpg
# 412     images/bags_working_moderate_3yrs.jpg
# 413     images/bags_working_moderate_4yrs.jpg
# 414     images/bags_working_moderate_5yrs.jpg
# 415         images/bags_working_high_1yrs.jpg
# 416         images/bags_working_high_2yrs.jpg
# 417         images/bags_working_high_3yrs.jpg
# 418         images/bags_working_high_4yrs.jpg
# 419         images/bags_working_high_5yrs.jpg
# 420       images/bags_repairable_low_1yrs.jpg
# 421       images/bags_repairable_low_2yrs.jpg
# 422       images/bags_repairable_low_3yrs.jpg
# 423       images/bags_repairable_low_4yrs.jpg
# 424       images/bags_repairable_low_5yrs.jpg
# 425  images/bags_repairable_moderate_1yrs.jpg
# 426  images/bags_repairable_moderate_2yrs.jpg
# 427  images/bags_repairable_moderate_3yrs.jpg
# 428  images/bags_repairable_moderate_4yrs.jpg
# 429  images/bags_repairable_moderate_5yrs.jpg
# 430      images/bags_repairable_high_1yrs.jpg
# 431      images/bags_repairable_high_2yrs.jpg
# 432      images/bags_repairable_high_3yrs.jpg
# 433      images/bags_repairable_high_4yrs.jpg
# 434      images/bags_repairable_high_5yrs.jpg
# 435             images/bags_dead_low_1yrs.jpg
# 436             images/bags_dead_low_2yrs.jpg
# 437             images/bags_dead_low_3yrs.jpg
# 438             images/bags_dead_low_4yrs.jpg
# 439             images/bags_dead_low_5yrs.jpg
# 440        images/bags_dead_moderate_1yrs.jpg
# 441        images/bags_dead_moderate_2yrs.jpg
# 442        images/bags_dead_moderate_3yrs.jpg
# 443        images/bags_dead_moderate_4yrs.jpg
# 444        images/bags_dead_moderate_5yrs.jpg
# 445            images/bags_dead_high_1yrs.jpg
# 446            images/bags_dead_high_2yrs.jpg
# 447            images/bags_dead_high_3yrs.jpg
# 448            images/bags_dead_high_4yrs.jpg
# 449            images/bags_dead_high_5yrs.jpg
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4660\972816151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bags_df['image_exists'] = bags_df['image_path'].apply(check_image_exists)

# %%
# Show a summary of years_used, condition, and description for Bags
print(bags_df[['years_used', 'condition', 'description']].describe(include='all'))
# Out:
#         years_used condition                              description
# count    45.000000        45                                       45
# unique         NaN         3                                        1
# top            NaN   Working  Zip works fine, fabric a bit discolored
# freq           NaN        15                                       45
# mean      3.000000       NaN                                      NaN
# std       1.430194       NaN                                      NaN
# min       1.000000       NaN                                      NaN
# 25%       2.000000       NaN                                      NaN
# 50%       3.000000       NaN                                      NaN
# 75%       4.000000       NaN                                      NaN
# max       5.000000       NaN                                      NaN

# %% [markdown]
# # Generalized Analysis for All Item Types
# The following cells will analyze the dataset for all item types, including sample counts, output class distributions, missing images, and summary statistics.

# %%
import pandas as pd
import os

df = pd.read_csv('../data/full_items_extended_dataset.csv')
image_dir = '../data/images/'

item_types = df['item_type'].unique()

for item in item_types:
    print(f'\n=== {item} ===')
    subset = df[df['item_type'] == item]
    print(f'Total samples: {len(subset)}')
    print('Output class distribution:')
    print(subset['output'].value_counts())
    # Check for missing images
    missing_images = subset[~subset['image_path'].apply(lambda x: os.path.isfile(os.path.join(image_dir, str(x))))]
    print(f'Missing images: {len(missing_images)}')
    if len(missing_images) > 0:
        print('Sample missing image paths:', missing_images['image_path'].head(3).tolist())
# Out:
# === Blenders/Mixers ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/blendersmixers_working_low_1yrs.jpg', 'images/blendersmixers_working_low_2yrs.jpg', 'images/blendersmixers_working_low_3yrs.jpg']
#
# === Electric Kettles ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/electrickettles_working_low_1yrs.jpg', 'images/electrickettles_working_low_2yrs.jpg', 'images/electrickettles_working_low_3yrs.jpg']
#
# === Water Purifier ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/waterpurifier_working_low_1yrs.jpg', 'images/waterpurifier_working_low_2yrs.jpg', 'images/waterpurifier_working_low_3yrs.jpg']
#
# === Lamps ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/lamps_working_low_1yrs.jpg', 'images/lamps_working_low_2yrs.jpg', 'images/lamps_working_low_3yrs.jpg']
#
# === Calculators ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/calculators_working_low_1yrs.jpg', 'images/calculators_working_low_2yrs.jpg', 'images/calculators_working_low_3yrs.jpg']
#
# === Plastic Toys ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/plastictoys_working_low_1yrs.jpg', 'images/plastictoys_working_low_2yrs.jpg', 'images/plastictoys_working_low_3yrs.jpg']
#
# === Shoes ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/shoes_working_low_1yrs.jpg', 'images/shoes_working_low_2yrs.jpg', 'images/shoes_working_low_3yrs.jpg']
#
# === Headphones ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/headphones_working_low_1yrs.jpg', 'images/headphones_working_low_2yrs.jpg', 'images/headphones_working_low_3yrs.jpg']
#
# === Chairs ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['images/chairs_working_low_1yrs.jpg', 'images/chairs_working_low_2yrs.jpg', 'images/chairs_working_low_3yrs.jpg']
#
# === Bags ===
# Total samples: 45
# Output class distribution:
# output
# Refurbish and Resell    20
# Salvage Components      15
# Recycle                 10
# Name: count, dtype: int64
# Missing images: 45
# Sample missing image paths: ['waste_classifier/data/images/used-school-bags-1511867190-3484608.jpg', 'waste_classifier/data/images/images.jpeg', 'images/bags_working_low_3yrs.jpg']

# %%
for item in item_types:
    print(f'\n=== {item} Summary Statistics ===')
    subset = df[df['item_type'] == item]
    print('years_used:')
    print(subset['years_used'].describe())
    print('condition:')
    print(subset['condition'].describe())
    # Description length
    desc_len = subset['description'].fillna('').apply(len)
    print('description length:')
    print(desc_len.describe())
# Out:
# === Blenders/Mixers Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     40.0
# std       0.0
# min      40.0
# 25%      40.0
# 50%      40.0
# 75%      40.0
# max      40.0
# Name: description, dtype: float64
#
# === Electric Kettles Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     41.0
# std       0.0
# min      41.0
# 25%      41.0
# 50%      41.0
# 75%      41.0
# max      41.0
# Name: description, dtype: float64
#
# === Water Purifier Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     35.0
# std       0.0
# min      35.0
# 25%      35.0
# 50%      35.0
# 75%      35.0
# max      35.0
# Name: description, dtype: float64
#
# === Lamps Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     43.0
# std       0.0
# min      43.0
# 25%      43.0
# 50%      43.0
# 75%      43.0
# max      43.0
# Name: description, dtype: float64
#
# === Calculators Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     45.0
# std       0.0
# min      45.0
# 25%      45.0
# 50%      45.0
# 75%      45.0
# max      45.0
# Name: description, dtype: float64
#
# === Plastic Toys Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     42.0
# std       0.0
# min      42.0
# 25%      42.0
# 50%      42.0
# 75%      42.0
# max      42.0
# Name: description, dtype: float64
#
# === Shoes Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     27.0
# std       0.0
# min      27.0
# 25%      27.0
# 50%      27.0
# 75%      27.0
# max      27.0
# Name: description, dtype: float64
#
# === Headphones Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     47.0
# std       0.0
# min      47.0
# 25%      47.0
# 50%      47.0
# 75%      47.0
# max      47.0
# Name: description, dtype: float64
#
# === Chairs Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     30.0
# std       0.0
# min      30.0
# 25%      30.0
# 50%      30.0
# 75%      30.0
# max      30.0
# Name: description, dtype: float64
#
# === Bags Summary Statistics ===
# years_used:
# count    45.000000
# mean      3.000000
# std       1.430194
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000
# Name: years_used, dtype: float64
# condition:
# count          45
# unique          3
# top       Working
# freq           15
# Name: condition, dtype: object
# description length:
# count    45.0
# mean     39.0
# std       0.0
# min      39.0
# 25%      39.0
# 50%      39.0
# 75%      39.0
# max      39.0
# Name: description, dtype: float64
